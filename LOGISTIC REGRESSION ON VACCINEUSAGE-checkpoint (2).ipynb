# %%
import pandas as pd
file=pd.read_csv("C:/Users/Dharniha V/Downloads/VaccineUsagePrediction/Vaccine Usage Prediction/Dataset/h1n1_vaccine_prediction.csv")
df=pd.DataFrame(file)
df
# Out:
#        unique_id  h1n1_worry  h1n1_awareness  antiviral_medication  \
# 0              0         1.0             0.0                   0.0
# 1              1         3.0             2.0                   0.0
# 2              2         1.0             1.0                   0.0
# 3              3         1.0             1.0                   0.0
# 4              4         2.0             1.0                   0.0
# ...          ...         ...             ...                   ...
# 26702      26702         2.0             0.0                   0.0
# 26703      26703         1.0             2.0                   0.0
# 26704      26704         2.0             2.0                   0.0
# 26705      26705         1.0             1.0                   0.0
# 26706      26706         0.0             0.0                   0.0
#
#        contact_avoidance  bought_face_mask  wash_hands_frequently  \
# 0                    0.0               0.0                    0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26707 entries, 0 to 26706
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   unique_id                  26707 non-null  int64
#  1   h1n1_worry                 26615 non-null  float64
#  2   h1n1_awareness             26591 non-null  float64
#  3   antiviral_medication       26636 non-null  float64
#  4   contact_avoidance          26499 non-null  float64
#  5   bought_face_mask           26688 non-null  float64
#  6   wash_hands_frequently      26665 non-null  float64
#  7   avoid_large_gatherings     26620 non-null  float64
#  8   reduced_outside_home_cont  26625 non-null  float64
#  9   avoid_touch_face           26579 non-null  float64
#  10  dr_recc_h1n1_vacc          24547 non-null  float64
#  11  dr_recc_seasonal_vacc      24547 non-null  float64
#  12  chronic_medic_condition    25736 non-null  float64
# ...

# %%
df.shape
# Out:
# (26707, 34)

# %%
for i in df:
    if df[i].dtype==object:
        x=df[i].mode()[0]
        df[i].fillna(x,inplace=True)
    else:
        x=df[i].mean()
        df[i].fillna(x,inplace=True)

# %%
df.isnull().sum()
# Out:
# unique_id                    0
# h1n1_worry                   0
# h1n1_awareness               0
# antiviral_medication         0
# contact_avoidance            0
# bought_face_mask             0
# wash_hands_frequently        0
# avoid_large_gatherings       0
# reduced_outside_home_cont    0
# avoid_touch_face             0
# dr_recc_h1n1_vacc            0
# dr_recc_seasonal_vacc        0
# chronic_medic_condition      0
# cont_child_undr_6_mnths      0
# is_health_worker             0
# has_health_insur             0
# is_h1n1_vacc_effective       0
# is_h1n1_risky                0
# sick_from_h1n1_vacc          0
# is_seas_vacc_effective       0
# is_seas_risky                0
# sick_from_seas_vacc          0
# age_bracket                  0
# qualification                0
# race                         0
# sex                          0
# income_level                 0
# marital_status               0
# housing_status               0
# employment                   0
# ...

# %%
df.describe()
# Out:
#           unique_id    h1n1_worry  h1n1_awareness  antiviral_medication  \
# count  26707.000000  26707.000000    26707.000000          26707.000000
# mean   13353.000000      1.618486        1.262532              0.048844
# std     7709.791156      0.908741        0.616805              0.215258
# min        0.000000      0.000000        0.000000              0.000000
# 25%     6676.500000      1.000000        1.000000              0.000000
# 50%    13353.000000      2.000000        1.000000              0.000000
# 75%    20029.500000      2.000000        2.000000              0.000000
# max    26706.000000      3.000000        2.000000              1.000000
#
#        contact_avoidance  bought_face_mask  wash_hands_frequently  \
# count       26707.000000      26707.000000           26707.000000
# mean            0.725612          0.068982               0.825614
# std             0.444473          0.253339               0.379150
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
plotting=df.hist(figsize=(12,12))

# %%
import matplotlib.pyplot as plt
plt.hist(x=df['no_of_adults'])
# Out:
# (array([ 8056.,     0.,   249., 14474.,     0.,     0.,  2803.,     0.,
#             0.,  1125.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <a list of 10 Patch objects>)

# %%
sns.boxplot(x=df["sick_from_h1n1_vacc"],y=df["sick_from_seas_vacc"])

# %%
plt.boxplot(x=df["reduced_outside_home_cont"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2ad7470b0d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2ad75f44a60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2ad7470bf10>],
#  'medians': [<matplotlib.lines.Line2D at 0x2ad75f44f40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2ad75f448e0>],
#  'means': []}

# %%
plt.bar(df['bought_face_mask'],height=df['h1n1_awareness'].values,color='r')
# Out:
# <BarContainer object of 26707 artists>

# %%
plt.scatter(df.h1n1_awareness,df.contact_avoidance,marker='+',color='y')

# %%
df.corr()
# Out:
#                            unique_id  h1n1_worry  h1n1_awareness  \
# unique_id                   1.000000    0.017804        0.003418
# h1n1_worry                  0.017804    1.000000        0.062081
# h1n1_awareness              0.003418    0.062081        1.000000
# antiviral_medication       -0.008463    0.089985       -0.010802
# contact_avoidance           0.009602    0.231965        0.088151
# bought_face_mask           -0.006641    0.155466        0.029953
# wash_hands_frequently       0.011097    0.292480        0.089376
# avoid_large_gatherings      0.004532    0.254137       -0.048697
# reduced_outside_home_cont   0.008995    0.245597       -0.067895
# avoid_touch_face            0.007555    0.246809        0.085646
# dr_recc_h1n1_vacc          -0.001987    0.143474        0.089452
# dr_recc_seasonal_vacc       0.001438    0.129469        0.068533
# chronic_medic_condition     0.005692    0.092824       -0.021939
# ...

# %%
df.corr().style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_39977_row0_col0, #T_39977_row1_col1, #T_39977_row2_col2, #T_39977_row3_col3, #T_39977_row4_col4, #T_39977_row5_col5, #T_39977_row6_col6, #T_39977_row7_col7, #T_39977_row8_col8, #T_39977_row9_col9, #T_39977_row10_col10, #T_39977_row11_col11, #T_39977_row12_col12, #T_39977_row13_col13, #T_39977_row14_col14, #T_39977_row15_col15, #T_39977_row16_col16, #T_39977_row17_col17, #T_39977_row18_col18, #T_39977_row19_col19, #T_39977_row20_col20, #T_39977_row21_col21, #T_39977_row22_col22, #T_39977_row23_col23, #T_39977_row24_col24 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_39977_row0_col1, #T_39977_row4_col14, #T_39977_row14_col8, #T_39977_row14_col18, #T_39977_row18_col15, #T_39977_row22_col12, #T_39977_row23_col5 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# ...

# %%
for i in df:
    if df[i].dtype==object:
        from sklearn.preprocessing import LabelEncoder
        le =LabelEncoder()
        df[i]=le.fit_transform(df[i])

# %%
x=df.drop(["h1n1_vaccine"],axis=1)
y=df["h1n1_vaccine"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# C:\Users\Dharniha V\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=model.predict(x_test)
print(y_pred)
# Out:
# [0 0 1 ... 0 0 0]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.8075627105952826

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_pred,y_test)
# Out:
# array([[3922,  778],
#        [ 250,  392]], dtype=int64)

# %%
from sklearn.metrics import classification_report
classification_report(y_pred,y_test)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.94      0.83      0.88      4700\n           1       0.34      0.61      0.43       642\n\n    accuracy                           0.81      5342\n   macro avg       0.64      0.72      0.66      5342\nweighted avg       0.87      0.81      0.83      5342\n'
